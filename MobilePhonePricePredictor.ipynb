# %% [markdown]
# <a href="https://colab.research.google.com/github/KPabsy/mobile-price-predictor/blob/main/MobilePhonePricePredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
cd /content/sample_data
# Out:
# /content/sample_data

# %%
df=pd.read_csv('Mobile_Price_Classification-220531-204702.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
x=df.drop(columns=["price_range"])
y=df["price_range"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75)

# Scale the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense,Dropout
from sklearn.preprocessing import StandardScaler

# %%
model=Sequential()
model.add(Dense(units=8,activation='relu',input_dim=x_train.shape[1]))
model.add(Dense(units=4,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 8)              │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             5 │
# ...

# %%
print(y.nunique())
print(y.unique())
# Out:
# 2
# [1 0]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4749 - loss: 0.7164 - val_accuracy: 0.4980 - val_loss: 0.7020
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4914 - loss: 0.6975 - val_accuracy: 0.5000 - val_loss: 0.6963
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5121 - loss: 0.6907 - val_accuracy: 0.5220 - val_loss: 0.6924
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5276 - loss: 0.6842 - val_accuracy: 0.5140 - val_loss: 0.6890
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5744 - loss: 0.6764 - val_accuracy: 0.5120 - val_loss: 0.6857
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5861 - loss: 0.6698 - val_accuracy: 0.5180 - val_loss: 0.6825
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5958 - loss: 0.6686 - val_accuracy: 0.5520 - val_loss: 0.6781
# Epoch 8/100
# ...

# %%
model.save('weights.keras')

# %%
import numpy as np
from sklearn.metrics import accuracy_score

# Get 5 random indices from the test set
num_samples = len(x_test)
random_indices = np.random.choice(num_samples, 5, replace=False)

# Select random samples from x_test and corresponding y_test
random_x_samples = x_test[random_indices]
random_y_true = y_test.iloc[random_indices]

# Make predictions using the loaded model
random_predictions_proba = loaded_model.predict(random_x_samples)

# Convert probabilities to binary predictions
random_binary_predictions = (random_predictions_proba > 0.5).astype(int)

print("Actual Y values for random samples:")
print(random_y_true.values.reshape(-1, 1))

print("\nPredicted binary values for random samples:")
print(random_binary_predictions)

# Calculate accuracy
accuracy = accuracy_score(random_y_true, random_binary_predictions)
print(f"\nAccuracy on 5 random samples: {accuracy:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Actual Y values for random samples:
# [[0]
#  [0]
#  [1]
#  [1]
#  [1]]
#
# Predicted binary values for random samples:
# [[0]
#  [0]
#  [1]
#  [1]
#  [0]]
#
# Accuracy on 5 random samples: 0.80
